# %%
import geopandas as gpd

# %%
gdf =gpd.read_file("C:/Users/OKWIR INNOCENT/Desktop/shape files/eastafrica")

# %%
gdf
# Out:
#       OBJECTID_1  OBJECTID          Name1 Name2 Name3              Type  \
# 0              1         1  Lake Victoria  None  None  Inland perennial
# 1              2         2  Lake Victoria  None  None  Inland perennial
# 2              3         3   Indian Ocean  None  None             Ocean
# 3              4         4  Lake Victoria  None  None  Inland perennial
# 4              5         5   Indian Ocean  None  None             Ocean
# ...          ...       ...            ...   ...   ...               ...
# 3875        3876      3876   Indian Ocean  None  None             Ocean
# 3876        3877      3877   Indian Ocean  None  None             Ocean
# 3877        3878      3878   Indian Ocean  None  None             Ocean
# 3878        3879      3879   Indian Ocean  None  None             Ocean
# 3879        3880      3880   Indian Ocean  None  None             Ocean
#
#       Shape_Leng  Shape_Le_1  Shape_Area  \
# 0       2.048804    2.048804    0.035836
# ...

# %%
gdf.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
gdf.plot()
# Out:
# <AxesSubplot:>
